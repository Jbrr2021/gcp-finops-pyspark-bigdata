# %% [markdown]
# <a href="https://colab.research.google.com/github/Jbrr2021/gcp-finops-pyspark-bigdata/blob/main/setup_inicializacao_pyspark_session_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =================================================================================
# ENGENHARIA DE DADOS EM BIG DATA / INTRODUÇÃO AO PYSPARK
# CONCEITO: Instalação e Inicialização de uma SparkSession Distribuída
#
# CONTEXTO DE NEGÓCIO (Pedido do Gestor):
# "Como nossa volumetria de logs de faturamento aumentou drasticamente, o Pandas travou.
# Configure o ambiente do Google Colab com o PySpark, inicialize uma sessão de
# processamento distribuído e monte a estrutura inicial para manipulação de Big Data."
# =================================================================================

# 1. Comando obrigatório para instalar o PySpark na máquina virtual do Colab
# !pip install pyspark -q

# 2. Importando a ferramenta de criação de sessão do Spark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, round  # Funções para manipular colunas

print("⏳ Inicializando o motor distribuído do Spark...")

# 3. Criando a SparkSession (O cérebro do Spark)
spark = SparkSession.builder \
    .appName("FinOpsBigData") \
    .getOrCreate()

print("✅ Motor PySpark ativo e pronto para processar milhões de linhas!")
# Out:
# ⏳ Inicializando o motor distribuído do Spark...
# ✅ Motor PySpark ativo e pronto para processar milhões de linhas!
